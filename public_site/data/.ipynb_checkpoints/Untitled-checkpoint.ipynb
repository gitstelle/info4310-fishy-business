# %%
import pandas as pd

# %%
water = pd.read_csv("freshwater-use-seafood.csv")
land = pd.read_csv("land-use-seafood.csv")
nitrogen = pd.read_csv("nitrogen-emissions-seafood.csv")
phos = pd.read_csv("phosphorous-emissions-seafood.csv")

# %%
water
# Out:
#                             Entity  Code  Year  \
# 0                Bivalves (farmed)   NaN  2021
# 1                    Carp (farmed)   NaN  2021
# 2                 Catfish (farmed)   NaN  2021
# 3                          Chicken   NaN  2021
# 4                Milkfish (farmed)   NaN  2021
# 5   Other freshwater fish (farmed)   NaN  2021
# 6       Other marine fish (farmed)   NaN  2021
# 7                  Salmon (farmed)   NaN  2021
# 8                 Seaweed (farmed)   NaN  2021
# 9                  Shrimp (farmed)   NaN  2021
# 10         Silver/bighead (farmed)   NaN  2021
# 11                Tilapia (farmed)   NaN  2021
# 12                  Trout (farmed)   NaN  2021
#
#     Freshwater use (m3 / kg edible weight)
# 0                                 0.000000
# 1                                 3.522775
# 2                                 2.094446
# 3                                 0.454700
# 4                                 0.282913
# ...

# %%
## getting rid of bivalves and seaweed and chicken

water_filtered = water[(water['Entity'] != "Bivalves (farmed)") & (water['Entity'] != "Seaweed (farmed)") & (water['Entity'] != "Chicken")]
land_filtered = land[(land['Entity'] != "Bivalves (farmed)") & (land['Entity'] != "Seaweed (farmed)") & (land['Entity'] != "Chicken")]
nit_filtered = nitrogen[(nitrogen['Entity'] != "Bivalves (farmed)") & (nitrogen['Entity'] != "Seaweed (farmed)") & (nitrogen['Entity'] != "Chicken")]
phos_filtered = phos[(phos['Entity'] != "Bivalves (farmed)") & (phos['Entity'] != "Seaweed (farmed)") & (phos['Entity'] != "Chicken")]
# Out:
#                             Entity  Code  Year  \
# 1                    Carp (farmed)   NaN  2021
# 2                 Catfish (farmed)   NaN  2021
# 4                Milkfish (farmed)   NaN  2021
# 5   Other freshwater fish (farmed)   NaN  2021
# 6       Other marine fish (farmed)   NaN  2021
# 7                  Salmon (farmed)   NaN  2021
# 9                  Shrimp (farmed)   NaN  2021
# 10         Silver/bighead (farmed)   NaN  2021
# 11                Tilapia (farmed)   NaN  2021
# 12                  Trout (farmed)   NaN  2021
#
#     Freshwater use (m3 / kg edible weight)
# 1                                 3.522775
# 2                                 2.094446
# 4                                 0.282913
# 5                                 0.362880
# 6                                 0.401395
# 7                                 0.155711
# 9                                 0.219165
# 10                                9.277280
# 11                                1.230468
# ...
